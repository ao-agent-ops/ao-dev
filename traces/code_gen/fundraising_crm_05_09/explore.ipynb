# %%
import json

with open("fundraising_crm_traj.jsonl", "r") as f:
    lines = f.readlines()

dicts = [json.loads(l) for l in lines]
print(len(dicts), "LLM calls")
# Out:
# 359 LLM calls

# %%
def pretty_display(raw_string: str):
    """
    Takes a raw string with escaped characters and prints it nicely formatted.
    """
    # Decode escaped sequences like \n, \t, \', etc.
    decoded = raw_string.encode().decode('unicode_escape')
    print(decoded)

# %%
for d in dicts:
    if "app.routes" in d["cache_key"]:
        print(f'"{d["cache_key"]}",')
# Out:
# "class_test_spec_gen_unit_fundraising_crm_tree_src.app.routes.Routes_0_sonnet3.7-nothink",
# "class_test_spec_gen_integration_fundraising_crm_tree_src.app.routes.Routes_0_sonnet3.7-nothink",
# "method_test_transpiling_gen_fundraising_crm_tree_src.app.routes.Routes_0_sonnet3.7-nothink",
# "method_test_transpiling_gen_fundraising_crm_tree_src.app.routes.Routes_1_sonnet3.7-nothink",
# "method_test_transpiling_review_fundraising_crm_tree_src.app.routes.Routes_0_sonnet3.7-nothink",
# "method_test_transpiling_fix_fundraising_crm_tree_src.app.routes.Routes_0_sonnet3.7-nothink",
# "method_test_transpiling_review_fundraising_crm_tree_src.app.routes.Routes_1_sonnet3.7-nothink",
# "method_test_transpiling_fix_fundraising_crm_tree_src.app.routes.Routes_1_sonnet3.7-nothink",
# "method_test_transpiling_review_fundraising_crm_tree_src.app.routes.Routes_2_sonnet3.7-nothink",
# "method_test_transpiling_review_fundraising_crm_tree_src.app.routes.Routes_3_sonnet3.7-nothink",
# "file_planner_analysis_fundraising_crm_tree_src.app.routes_0_sonnet3.7-nothink",
# "file_planner_analysis_fundraising_crm_tree_src.app.routes_1_sonnet3.7-nothink",
# "file_planner_iterate_fundraising_crm_tree_src.app.routes_0_sonnet3.7-nothink",
# "file_planner_iterate_fundraising_crm_tree_src.app.routes_1_sonnet3.7-nothink",
# "file_planner_iterate_fundraising_crm_tree_src.app.routes_2_sonnet3.7-nothink",
# "file_planner_iterate_fundraising_crm_tree_src.app.routes_3_sonnet3.7-nothink",
# "file_planner_iterate_fundraising_crm_tree_src.app.routes_4_sonnet3.7-nothink",
# "file_planner_iterate_fundraising_crm_tree_src.app.routes_5_sonnet3.7-nothink",
# "file_transpiler_analysis_fundraising_crm_tree_src.app.routes_0_sonnet3.7-nothink",
# "file_transpiler_analysis_fundraising_crm_tree_src.app.routes_1_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_0_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_1_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_2_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_3_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_4_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_5_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_6_sonnet3.7-nothink",
# "file_transpiler_analysis_fundraising_crm_tree_src.app.routes_2_sonnet3.7-nothink",
# "file_transpiler_analysis_fundraising_crm_tree_src.app.routes_3_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_7_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_8_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_9_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_10_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_11_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_12_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_13_sonnet3.7-nothink",
# "file_transpiler_analysis_fundraising_crm_tree_src.app.routes_4_sonnet3.7-nothink",
# "file_transpiler_analysis_fundraising_crm_tree_src.app.routes_5_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_14_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_15_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_16_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_17_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_18_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_19_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_20_sonnet3.7-nothink",
# "file_transpiler_analysis_fundraising_crm_tree_src.app.routes_6_sonnet3.7-nothink",
# "file_transpiler_analysis_fundraising_crm_tree_src.app.routes_7_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_21_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_22_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_23_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_24_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_25_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_26_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_27_sonnet3.7-nothink",
# "file_transpiler_analysis_fundraising_crm_tree_src.app.routes_8_sonnet3.7-nothink",
# "file_transpiler_analysis_fundraising_crm_tree_src.app.routes_9_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_28_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_29_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_30_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_31_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_32_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_33_sonnet3.7-nothink",
# "file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_34_sonnet3.7-nothink",

# %%
def print_entry(cache_key, entry_type):
    for d in dicts:
        if cache_key == d["cache_key"]:
            pretty_display(d[entry_type])

# %%
cache_key = "file_planner_analysis"

# approach_correct = true
# missing_dependencies = false
# irrelevant_dependencies = false

for d in dicts:
    if cache_key in d["cache_key"]:
        if "approach_correct = false" in d["output"]:
            print("Approach false", d["cache_key"])
        if "missing_dependencies = true" in d["output"]:
            print("missing deps", d["cache_key"])
        if "irrelevant_dependencies = true" in d["output"]:
            print("irrelevant deps", d["cache_key"])
# Out:
# missing deps file_planner_analysis_fundraising_crm_tree_src.database.db_operations_0_sonnet3.7-nothink

# %%
for d in dicts:
    if "test" in d["prompt"]:
        print(d["cache_key"])
# Out:
# class_test_spec_gen_unit_fundraising_crm_tree_src.backend_services.utils.HashFunc_0_sonnet3.7-nothink
# class_test_spec_gen_unit_fundraising_crm_tree_src.backend_services.agent_service.AgentService_0_sonnet3.7-nothink
# class_test_spec_gen_unit_fundraising_crm_tree_src.database.db_operations.PostgresOperations_0_sonnet3.7-nothink
# class_test_spec_gen_unit_fundraising_crm_tree_src.database.schema.BaseTable_0_sonnet3.7-nothink
# class_test_spec_gen_unit_fundraising_crm_tree_src.backend_services.data_models.CompanyNote_0_sonnet3.7-nothink
# class_test_spec_gen_unit_fundraising_crm_tree_src.backend_services.data_models.Company_0_sonnet3.7-nothink
# class_test_spec_gen_unit_fundraising_crm_tree_src.backend_services.admin_service.AdminAgentService_0_sonnet3.7-nothink
# class_test_spec_gen_integration_fundraising_crm_tree_src.backend_services.utils.HashFunc_0_sonnet3.7-nothink
# class_test_spec_gen_unit_fundraising_crm_tree_src.app.app.FlaskApp_0_sonnet3.7-nothink
# class_test_spec_gen_unit_fundraising_crm_tree_src.backend_services.data_models.Contact_0_sonnet3.7-nothink
# class_test_spec_gen_unit_fundraising_crm_tree_src.backend_services.data_models.ContactNote_0_sonnet3.7-nothink
# class_test_spec_gen_unit_fundraising_crm_tree_src.app.routes.Routes_0_sonnet3.7-nothink
# class_test_spec_gen_unit_fundraising_crm_tree_src.backend_services.data_models.EmailTemplate_0_sonnet3.7-nothink
# class_test_spec_gen_integration_fundraising_crm_tree_src.database.db_operations.PostgresOperations_0_sonnet3.7-nothink
# class_test_spec_gen_unit_fundraising_crm_tree_src.backend_services.data_models.Agent_0_sonnet3.7-nothink
# class_test_spec_gen_unit_fundraising_crm_tree_src.database.schema.Schema_0_sonnet3.7-nothink
# class_test_spec_gen_integration_fundraising_crm_tree_src.backend_services.agent_service.AgentService_0_sonnet3.7-nothink
# class_test_spec_gen_unit_fundraising_crm_tree_src.backend_services.data_models.Task_0_sonnet3.7-nothink
# class_test_spec_gen_integration_fundraising_crm_tree_src.database.schema.BaseTable_0_sonnet3.7-nothink
# class_test_spec_gen_integration_fundraising_crm_tree_src.backend_services.data_models.CompanyNote_0_sonnet3.7-nothink
# class_test_spec_gen_integration_fundraising_crm_tree_src.backend_services.data_models.Company_0_sonnet3.7-nothink
# class_test_spec_gen_integration_fundraising_crm_tree_src.backend_services.admin_service.AdminAgentService_0_sonnet3.7-nothink
# class_test_spec_gen_integration_fundraising_crm_tree_src.app.app.FlaskApp_0_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.utils.HashFunc_0_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.utils.HashFunc_1_sonnet3.7-nothink
# class_test_spec_gen_integration_fundraising_crm_tree_src.backend_services.data_models.Contact_0_sonnet3.7-nothink
# class_test_spec_gen_integration_fundraising_crm_tree_src.backend_services.data_models.ContactNote_0_sonnet3.7-nothink
# class_test_spec_gen_integration_fundraising_crm_tree_src.app.routes.Routes_0_sonnet3.7-nothink
# class_test_spec_gen_integration_fundraising_crm_tree_src.backend_services.data_models.EmailTemplate_0_sonnet3.7-nothink
# class_test_spec_gen_integration_fundraising_crm_tree_src.backend_services.data_models.Agent_0_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.database.db_operations.PostgresOperations_0_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.database.db_operations.PostgresOperations_1_sonnet3.7-nothink
# class_test_spec_gen_integration_fundraising_crm_tree_src.database.schema.Schema_0_sonnet3.7-nothink
# class_test_spec_gen_integration_fundraising_crm_tree_src.backend_services.data_models.Task_0_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.agent_service.AgentService_0_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.agent_service.AgentService_1_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.admin_service.AdminAgentService_1_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.admin_service.AdminAgentService_0_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.app.app.FlaskApp_0_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.app.app.FlaskApp_1_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.app.routes.Routes_0_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.app.routes.Routes_1_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.database.schema.BaseTable_0_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.database.schema.Schema_0_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.data_models.CompanyNote_0_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.data_models.Company_0_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.data_models.EmailTemplate_0_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.data_models.ContactNote_0_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.data_models.Contact_0_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.data_models.Company_1_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.database.schema.Schema_1_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.data_models.CompanyNote_1_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.database.schema.BaseTable_1_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.data_models.Contact_1_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.data_models.Task_0_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.data_models.EmailTemplate_1_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.data_models.ContactNote_1_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.data_models.Agent_0_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.data_models.Agent_1_sonnet3.7-nothink
# method_test_transpiling_gen_fundraising_crm_tree_src.backend_services.data_models.Task_1_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.utils.HashFunc_0_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.utils.HashFunc_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.utils.HashFunc_1_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.utils.HashFunc_1_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.db_operations.PostgresOperations_0_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.database.db_operations.PostgresOperations_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.db_operations.PostgresOperations_1_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.database.db_operations.PostgresOperations_1_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.admin_service.AdminAgentService_0_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.admin_service.AdminAgentService_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.admin_service.AdminAgentService_1_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.admin_service.AdminAgentService_1_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.app.routes.Routes_0_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.app.routes.Routes_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.app.routes.Routes_1_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.app.routes.Routes_1_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.schema.BaseTable_0_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.database.schema.BaseTable_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.schema.Schema_0_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.database.schema.Schema_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.CompanyNote_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.Company_0_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.data_models.Company_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.EmailTemplate_0_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.data_models.EmailTemplate_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.agent_service.AgentService_1_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.ContactNote_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.Contact_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.Company_1_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.schema.Schema_1_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.database.schema.Schema_1_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.CompanyNote_1_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.data_models.CompanyNote_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.schema.BaseTable_1_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.database.schema.BaseTable_1_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.Contact_1_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.data_models.Contact_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.Task_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.EmailTemplate_1_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.data_models.EmailTemplate_1_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.ContactNote_1_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.data_models.ContactNote_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.Agent_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.Agent_1_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.data_models.Agent_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.agent_service.AgentService_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.Task_1_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.utils.HashFunc_2_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.utils.HashFunc_2_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.utils.HashFunc_3_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.utils.HashFunc_3_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.app.app.FlaskApp_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.app.app.FlaskApp_1_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.db_operations.PostgresOperations_2_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.schema.BaseTable_2_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.database.schema.BaseTable_2_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.schema.Schema_2_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.database.schema.Schema_2_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.Company_2_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.data_models.Company_1_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.EmailTemplate_2_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.schema.Schema_3_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.database.schema.Schema_3_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.CompanyNote_2_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.data_models.CompanyNote_1_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.schema.BaseTable_3_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.Contact_2_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.EmailTemplate_3_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.ContactNote_2_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.data_models.ContactNote_1_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.Agent_2_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.data_models.Agent_1_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.app.routes.Routes_2_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.utils.HashFunc_4_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.app.routes.Routes_3_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.utils.HashFunc_5_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.schema.BaseTable_4_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.schema.Schema_4_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.database.schema.Schema_4_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.Company_3_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.db_operations.PostgresOperations_3_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.schema.Schema_5_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.CompanyNote_3_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.ContactNote_3_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.data_models.ContactNote_2_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.Agent_3_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.data_models.Agent_2_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.schema.Schema_6_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.database.schema.Schema_5_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.ContactNote_4_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.data_models.Agent_4_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.schema.Schema_7_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.admin_service.AdminAgentService_2_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.admin_service.AdminAgentService_3_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.app.app.FlaskApp_0_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.app.app.FlaskApp_1_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.app.app.FlaskApp_2_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.app.app.FlaskApp_3_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.admin_service.AdminAgentService_2_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.admin_service.AdminAgentService_3_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.app.app.FlaskApp_2_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.app.app.FlaskApp_3_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.admin_service.AdminAgentService_4_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.admin_service.AdminAgentService_5_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.app.app.FlaskApp_5_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.app.app.FlaskApp_4_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.database.db_operations.PostgresOperations_2_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.db_operations.PostgresOperations_4_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.agent_service.AgentService_0_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.agent_service.AgentService_2_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.app.app.FlaskApp_5_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.app.app.FlaskApp_6_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.app.app.FlaskApp_4_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.admin_service.AdminAgentService_4_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.app.app.FlaskApp_7_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.admin_service.AdminAgentService_6_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.app.app.FlaskApp_6_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.agent_service.AgentService_1_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.database.db_operations.PostgresOperations_3_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.app.app.FlaskApp_8_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.agent_service.AgentService_3_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.db_operations.PostgresOperations_5_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.app.app.FlaskApp_7_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.app.app.FlaskApp_9_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.backend_services.admin_service.AdminAgentService_5_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.backend_services.admin_service.AdminAgentService_7_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.app.app.FlaskApp_8_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.database.db_operations.PostgresOperations_4_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.app.app.FlaskApp_9_sonnet3.7-nothink
# method_test_transpiling_review_fundraising_crm_tree_src.database.db_operations.PostgresOperations_6_sonnet3.7-nothink
# method_test_transpiling_fix_fundraising_crm_tree_src.database.db_operations.PostgresOperations_5_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.schema_1_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.schema_3_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_1_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_3_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_5_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_8_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_10_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_12_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_15_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_17_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_19_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_22_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_24_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_26_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_29_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_31_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_33_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.backend_services.data_models_1_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.backend_services.data_models_3_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.backend_services.utils_1_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.backend_services.agent_service_1_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.backend_services.agent_service_3_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.backend_services.admin_service_1_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.backend_services.admin_service_3_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_1_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_3_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_5_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_8_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_10_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_12_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_15_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_17_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_19_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_22_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_24_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_26_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_29_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_31_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_33_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.app_1_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.app_3_sonnet3.7-nothink

# %%
print_entry("file_planner_iterate_fundraising_crm_tree_src.app.routes_0_sonnet3.7-nothink", "output")
# Out:
# I'll analyze the `app.routes.py` file to determine the best implementation approach.
#
# <analysis>
# ```md
# # Difficulty Analysis
# This file is of **medium** complexity. The Routes class contains numerous methods for handling different HTTP routes, but most of them follow a similar pattern:
# 1. Extract data from request
# 2. Call appropriate service method
# 3. Redirect or render template
#
# While there are many methods, they're mostly straightforward and follow consistent patterns. The complexity comes from the sheer number of routes and ensuring proper authentication and error handling across all of them.
#
# # Dependency Analysis
# The file depends on:
# - Flask framework (Flask, request, session, redirect, url_for, render_template, flash, jsonify)
# - Backend services (AgentService, AdminAgentService)
# - Database components (Schema, PostgresOperations)
# - Data models (Agent, CompanyNote, Company, Contact, ContactNote, Task, EmailTemplate)
# - Logging
#
# All these dependencies are necessary for implementing the routes. The file acts as a controller layer connecting the frontend (templates) with the backend services.
#
# ## Missing Dependencies
# No missing dependencies identified. All necessary imports are present.
#
# ## Irrelevant Dependencies
# No irrelevant dependencies identified. All imports are used in the implementation.
#
# # Implementation Approach
# 1. **Initialize the Routes class**: Implement the constructor to store references to the Flask app and services.
#
# 2. **Implement register_routes method**: Map all URL patterns to their respective handler methods using Flask's route decorators.
#
# 3. **Implement authentication routes**: Login, logout, and session management.
#
# 4. **Implement CRUD operations for each entity**:
#    - Companies (list, view, add, update, delete)
#    - Company notes (add, edit, delete)
#    - Contacts (list, view, add, update, delete)
#    - Contact notes (add, edit, delete)
#    - Tasks (list, view, add, update, delete, mark complete)
#    - Email functionality
#    - Settings
#
# 5. **Implement admin-specific routes**: Agent management (list, view, edit, delete, create)
#
# 6. **Add error handling and authentication checks**: Ensure users are logged in before accessing protected routes.
#
# ## Dedicated Implementations
# No dedicated implementations needed. While there are many methods, they follow similar patterns and can be implemented together.
# ```
# </analysis>
#
# <structured_analysis>
# ```toml
# difficulty = "medium"
# fix = ""
# dependency_analysis = """
# The file depends on Flask framework components (Flask, request, session, redirect, url_for, render_template, flash, jsonify), backend services (AgentService, AdminAgentService), database components (Schema, PostgresOperations), and data models (Agent, CompanyNote, Company, Contact, ContactNote, Task, EmailTemplate). All these dependencies are necessary for implementing the routes as this file serves as the controller layer connecting the frontend templates with the backend services.
# """
# missing_dependencies = false
# irrelevant_dependencies = false
# dedicated_implementations = []
# approach = """
# 1. Implement the constructor to store references to the Flask app and services.
# 2. Implement the register_routes method to map all URL patterns to their respective handler methods using Flask's route decorators.
# 3. Implement authentication routes (login, logout) with proper session management.
# 4. Implement CRUD operations for each entity:
#    - Companies (list, view, add, update, delete)
#    - Company notes (add, edit, delete)
#    - Contacts (list, view, add, update, delete)
#    - Contact notes (add, edit, delete)
#    - Tasks (list, view, add, update, delete, mark complete)
#    - Email functionality
#    - Settings
# 5. Implement admin-specific routes for agent management (list, view, edit, delete, create)
# 6. Add error handling and authentication checks to ensure users are logged in before accessing protected routes.
#
# Each route handler will follow a similar pattern:
# - Extract data from request
# - Call appropriate service method
# - Redirect to appropriate page or render template with data
# """
# ```
# </structured_analysis>

# %%
search_str = "implemented the BaseTable class and started implementing the Schema"

for i, d in enumerate(dicts):
    if search_str in d["prompt"]:
        print("in", i)
    if search_str in d["output"]:
        print("out", i)
# Out:
# out 2
# in 3
# 0 0

# %%
search_str = "file_transpiler_transpilation_fundraising_crm_tree_src.database.schema_0_sonnet3.7-nothink"

for i, d in enumerate(dicts):
    if search_str == d["cache_key"]:
        print("="*15, "SYSTEM MSG:", "="*15)
        pretty_display(d["system_msg"])

        print("\n"*5, "="*15, "PROMPT:", "="*15, "\n"*5)
        pretty_display(d["prompt"])

        print("\n"*5, "="*15, "OUTPUT:", "="*15, "\n"*5)
        pretty_display(d["output"])
# Out:
# =============== SYSTEM MSG: ===============
# I am trying to transpile my Python-like implementation plans into actual code.
#
# I am trying to transpile my Python-like implementation plans into actual code.
# By node, I am going to refer to a function, method, or class that needs to be implemented.
#
#
# - Be careful to respect variable and function names, or the code will not compile.
# - Be sure to respect the signatures and call order.
# - Be careful to respect argument types and order, especially for object initialization.
#     - Remember that object initialization can only occur on concrete classes, not interfaces.
#     - Subsequent method calls should be on interfaces.
# - Depending on language, be sure to always unwrap/check optional types before using them.
#
#
# # Other Generic Python Guidelines
# - Assume any needed library is already installed with pip.
#     - It can just be imported like the standard libraries. For example, `import numpy as np` or `import requests`.
# - Use ''' for docstrings, instead of """.
#     - This is to help me parse and serialize the code without escaping issues.
#     - For example, `'''This is a docstring'''` instead of `"""This is a docstring"""`.
# - When generating a method in isolation, do not add the class-level indentation. I'll handle that when I put it in the class.
#
#
# # Using/Updating Python Imports
# - I have a provided a list of initial imports.
#     - In most cases, they are enough to complete the task.
# - In some cases, you may need to update the imports.
#     - Be sure the respect the paths of the code elements.
#     - If you do now know the exact, explain what you need, and I'll update them for you.
# - I will give you the option to specify new imports if needed.
#     - Leave it empty, or even absent, if no new imports are needed.
#     - Only use it if necessary.
#
#
# # Python Interface Guidelines
# Write a python interface as a regular class.
# When a method is concrete (rare), just write the method.
# When a method is abstract, raise a `NotImplementedError('Inherit me!')`.
# Unless otherwise specified, do not add fancy decorators for abstract methods or overriden methods.
#
# For example:
# ```py
# class InterfaceName:
#     '''Interface description'''
#     def abstract_method(self, arg1: int) -> str:
#         '''Abstract method description'''
#         raise NotImplementedError('Inherit me!')
#
#     def concrete_method(self, arg1: int) -> str:
#         '''Concrete method description'''
#         # Concrete method body
#         ...
#
#
#
# You will help me directly implement a file or review the direct transpile of a file.
#
#
#
#
# - Be careful to respect variable and function names, or the code will not compile.
# - Be sure to respect the signatures and call order.
# - Be careful to respect argument types and order, especially for object initialization.
#     - Remember that object initialization can only occur on concrete classes, not interfaces.
#     - Subsequent method calls should be on interfaces.
# - Depending on language, be sure to always unwrap/check optional types before using them.
#
#
# # Other Generic Python Guidelines
# - Assume any needed library is already installed with pip.
#     - It can just be imported like the standard libraries. For example, `import numpy as np` or `import requests`.
# - Use ''' for docstrings, instead of """.
#     - This is to help me parse and serialize the code without escaping issues.
#     - For example, `'''This is a docstring'''` instead of `"""This is a docstring"""`.
# - When generating a method in isolation, do not add the class-level indentation. I'll handle that when I put it in the class.
#
#
# # Using/Updating Python Imports
# - I have a provided a list of initial imports.
#     - In most cases, they are enough to complete the task.
# - In some cases, you may need to update the imports.
#     - Be sure the respect the paths of the code elements.
#     - If you do now know the exact, explain what you need, and I'll update them for you.
# - I will give you the option to specify new imports if needed.
#     - Leave it empty, or even absent, if no new imports are needed.
#     - Only use it if necessary.
#
#
# # Python Interface Guidelines
# Write a python interface as a regular class.
# When a method is concrete (rare), just write the method.
# When a method is abstract, raise a `NotImplementedError('Inherit me!')`.
# Unless otherwise specified, do not add fancy decorators for abstract methods or overriden methods.
#
# For example:
# ```py
# class InterfaceName:
#     '''Interface description'''
#     def abstract_method(self, arg1: int) -> str:
#         '''Abstract method description'''
#         raise NotImplementedError('Inherit me!')
#
#     def concrete_method(self, arg1: int) -> str:
#         '''Concrete method description'''
#         # Concrete method body
#         ...
#
#
# # Direct Transpilation Guidelines
# We will directly transpile the full file. You must generated complete, compilable, running code in one go.
#
# ## Re-evaluation
# In some cases, I may ask you to re-evaluate the current implementation in light of an issue/bug.
# Be sure to adjust the implementation to fix the issue/bug.
# The code should be 'stable'. Meaning that it should change only as necessary.
#
#
# # Staying Language-Agnostic
#
# Even though the specs are in Python, I am only using Python syntax for convenience.
# I want the plan to be language-agnostic and high-level, so that I may later convert it to any language.
# For example:
# - Instead of saying "Use the `request` library to make an GET request", you should say "Use an HTTP GET request to fetch the data".
# - Instead of saying "Use the `random` library to generate a random number", you should say "Generate a random number".
#
# However, you can use Python's types and standard library for variable declarations.
# - For example, you can use `t.List[int]` to denote a list of integers.
# - Or `t.IO` to denote a file object.
# - Or `t.Optional` to denote an optional value.
# - Or `t.Dict` to denote a dictionary.
# - Etc.
#
# You can also use it for fairly universal concepts such as arrays, lists, locks, classes, methods, etc which are common across languages.
# Also, arithmetic operations, control-flow operations, function calls, etc. can be in Python.
# That's because these can easily be translated to any language.
#
# Be specific about integer widths. For example, if an integer is 16-bit, 32-bit, 64-bit, etc. That's because some target languages may have different integer widths.
#
# If a class is Enum or NamedTuple, then its implementation is already complete. No need to plan it out.
#
# When something is very Python specific, you should write pseudo-code that is language-agnostic.
# Like instead of:
# x = requests.get(url)
# You should write:
# x = ... # Use an HTTP GET request to fetch the data from the URL.
#
# Instead of:
# file_handle = open("file.txt", "r")
# You should write:
# file_handle = ... # Open the file "file.txt" in read mode.
#
#
#
#
#
#  =============== PROMPT: ===============
#
#
#
#
#
#
# _______________
# Dependencies:
# _______
# Auxiliary Dependencies:
# ___The content for database/schema.sql: CREATE TABLE companies (
#     company_id BIGINT NOT NULL PRIMARY KEY,
#     name TEXT,
#     main_contact_id BIGINT,
#     target_funding DOUBLE PRECISION,
#     grant_type TEXT,
#     status TEXT,
#     renewal_date TIMESTAMP
# );
#
# CREATE TABLE company_notes (
#     company_note_id BIGINT NOT NULL PRIMARY KEY,
#     company_id BIGINT REFERENCES companies(company_id),
#     create_time TIMESTAMP,
#     note TEXT
# );
#
# CREATE TABLE agents (
#     agent_id BIGINT NOT NULL PRIMARY KEY,
#     name TEXT,
#     email TEXT,
#     phone TEXT,
#     org TEXT,
#     role TEXT,
#     is_admin BOOLEAN,
#     password TEXT
# );
#
# CREATE TABLE contacts (
#     contact_id BIGINT NOT NULL PRIMARY KEY,
#     name TEXT,
#     email TEXT,
#     company_id BIGINT REFERENCES companies(company_id),
#     assigned_agent_id BIGINT REFERENCES agents(agent_id),
#     status TEXT
# );
#
# CREATE TABLE contact_notes (
#     contact_note_id BIGINT NOT NULL PRIMARY KEY,
#     contact_id BIGINT REFERENCES contacts(contact_id),
#     assigned_agent_id BIGINT REFERENCES agents(agent_id),
#     create_time TIMESTAMP,
#     subject TEXT,
#     note TEXT
# );
#
#
# CREATE TABLE tasks (
#     task_id BIGINT NOT NULL PRIMARY KEY,
#     assigned_agent_id BIGINT REFERENCES agents(agent_id),
#     contact_id BIGINT REFERENCES contacts(contact_id),
#     company_id BIGINT REFERENCES companies(company_id),
#     name TEXT,
#     description TEXT,
#     due_time TIMESTAMP,
#     status TEXT
# );
#
# CREATE TABLE email_templates (
#     template_id BIGINT NOT NULL PRIMARY KEY,
#     email_subject TEXT,
#     email_text TEXT
# );___
# _______
# _______________
# ---
# Here is the overall approach for transpilation the file database/schema.py:
# 1. Implement the BaseTable class:
#    - Implement the constructor to store all table metadata (name, columns, types, keys)
#    - Implement simple getter methods for column names and types
#    - Implement the create_table_postgres_sql method to return the SQL statement
#
# 2. Implement the Schema class:
#    - Implement the constructor to initialize empty collections for tables
#    - Implement the add_table method to add tables to both the list and dictionary
#    - Implement the get_tables_from_sql_statement method:
#      - Use regular expressions to extract CREATE TABLE statements
#      - For each statement, parse out table name and column definitions
#      - For each column definition, determine:
#        - Column name and type
#        - If it's a primary key
#        - If it has foreign key references
#      - Create BaseTable instances with the parsed information
#      - Add each table to the schema
#    - Implement the create_crm_schema static method to read the schema file and create a Schema instance
#
# 3. Special attention for SQL parsing:
#    - Handle multi-line SQL statements
#    - Correctly identify PRIMARY KEY constraints
#    - Extract foreign key references including referenced table and column
#    - Handle various SQL syntax patterns for column definitions
#
# ---
# Original API:
# """
# Data models define all tables in a database.
# Use this information to write SQL statements.
# """
# import typing as t
# #include database/schema.sql
#
#
# class BaseTable:
#     """This is the base class for representing a table in the crm database."""
#     def __init__(self,
#                  table_name: str,
#                  create_table_sql_statement: str,
#                  column_names: t.List[str],
#                  column_types: t.List[str],   #in postgres types (e.g., 'BIGINT', 'TEXT')
#                  primary_key: str = 'id',
#                  foreign_key_ref: t.Dict[str, t.Tuple[str]] = None,
#                  ):
#         """Create an attribute for each of the input variables"""
#         pass
#
#     def column_names(self) -> t.List[str]:
#         """Return column names"""
#         pass
#
#     def column_postgres_types(self) -> t.List[str]:
#         """Return a list of column types"""
#         pass
#
#     def create_table_postgres_sql(self) -> str:
#         """Return a CREATE TABLE sql statement in Postgres syntax
#         """
#         pass
#
#
#
# class Schema:
#     '''Holds all tables in the database schema'''
#
#     def __init__(self, schema_sql_statement: str=''):
#         '''Initialize a database schema based on the schema definition sql statement.'''
#         self.schema_sql_statement = schema_sql_statement
#         self.tables: t.List[BaseTable]
#         self.table_dictionary: t.Dict[str, BaseTable]   # table_name: BaseTable
#         self.get_tables_from_sql_statement()
#
#     def add_table(self, table: BaseTable):
#         """
#         Add a table to the schema, to both self.tables and self.table_dictionary
#         """
#         pass
#
#     def get_tables_from_sql_statement(self):
#         """
#         Parse the self.schema_sql_statement, which contains a list of "create table" sql statements
#         Each sql statement defines table name, column names, column types, primary key and foreign key references
#         Create these tables based on the parsed results and add them.
#         Use database/schema.sql as an example.
#         """
#         pass
#
#     @staticmethod
#     def create_crm_schema() -> 'Schema':
#         """
#         Create the schema of our CRM database
#         """
#         with open('schema.sql') as f:
#             schema_str = f.read()
#         return Schema(schema_str)
#
# Full Plan:
# """
# Data models define all tables in a database.
# Use this information to write SQL statements.
# """
# import typing as t
# import re
# import os
#
#
#
#
#
#
#
# class BaseTable:
#     """This is the base class for representing a table in the crm database."""
#
#     def __init__(self,
#                  table_name: str,
#                  create_table_sql_statement: str,
#                  column_names: t.List[str],
#                  column_types: t.List[str],   #in postgres types (e.g., 'BIGINT', 'TEXT')
#                  primary_key: str = 'id',
#                  foreign_key_ref: t.Dict[str, t.Tuple[str]] = None,
#                  ):
#         """Create an attribute for each of the input variables"""
#         self.table_name = table_name
#         self.create_table_sql_statement = create_table_sql_statement
#         self.column_names_list = column_names
#         self.column_types_list = column_types
#         self.primary_key = primary_key
#         self.foreign_key_ref = foreign_key_ref if foreign_key_ref else {}
#
#     def column_names(self) -> t.List[str]:
#         """Return column names"""
#         return self.column_names_list
#
#     def column_postgres_types(self) -> t.List[str]:
#         """Return a list of column types"""
#         return self.column_types_list
#
#     def create_table_postgres_sql(self) -> str:
#         """Return a CREATE TABLE sql statement in Postgres syntax"""
#         return self.create_table_sql_statement
#
#
#
#
# class Schema:
#     '''Holds all tables in the database schema'''
#
#     def __init__(self, schema_sql_statement: str=''):
#         '''Initialize a database schema based on the schema definition sql statement.'''
#         self.schema_sql_statement = schema_sql_statement
#         self.tables: t.List[BaseTable] = []
#         self.table_dictionary: t.Dict[str, BaseTable] = {}  # table_name: BaseTable
#         if schema_sql_statement:
#             self.get_tables_from_sql_statement()
#
#     def add_table(self, table: BaseTable):
#         """Holds all tables in the database schema"""
#
#     def __init__(self, schema_sql_statement: str=''):
#         '''Initialize a database schema based on the schema definition sql statement.'''
#         self.schema_sql_statement = schema_sql_statement
#         self.tables: t.List[BaseTable] = []
#         self.table_dictionary: t.Dict[str, BaseTable] = {}  # table_name: BaseTable
#         if schema_sql_statement:
#             self.get_tables_from_sql_statement()
#
#     def add_table(self, table: BaseTable):
#         """
#         Add a table to the schema, to both self.tables and self.table_dictionary
#         """
#         self.tables.append(table)
#         self.table_dictionary[table.table_name] = table
#
#     def get_tables_from_sql_statement(self):
#         """
#         Parse the self.schema_sql_statement, which contains a list of "create table" sql statements
#         Each sql statement defines table name, column names, column types, primary key and foreign key references
#         Create these tables based on the parsed results and add them.
#         Use database/schema.sql as an example.
#         """
#         # Split the SQL statement by CREATE TABLE statements
#         create_table_statements = re.findall(r'CREATE TABLE\s+(\w+)\s*\(([\s\S]*?)\);', self.schema_sql_statement, re.IGNORECASE)
#
#         for table_name, table_content in create_table_statements:
#             # Extract column definitions
#             column_defs = [col.strip() for col in table_content.split(',')]
#             column_names = []
#             column_types = []
#             primary_key = None
#             foreign_key_refs = {}
#
#             for col_def in column_defs:
#                 # Skip empty lines
#                 if not col_def:
#                     continue
#
#                 # Check if this is a primary key constraint
#                 if 'PRIMARY KEY' in col_def.upper() and not col_def.strip().startswith('('):
#                     # This is a column with PRIMARY KEY constraint
#                     parts = col_def.split()
#                     col_name = parts[0]
#                     primary_key = col_name
#                     column_names.append(col_name)
#                     column_types.append(' '.join(parts[1:-2]))  # Exclude PRIMARY KEY
#                 elif 'REFERENCES' in col_def.upper():
#                     # This is a foreign key reference
#                     parts = col_def.split()
#                     col_name = parts[0]
#                     column_names.append(col_name)
#
#                     # Extract the type (everything between column name and REFERENCES)
#                     type_parts = []
#                     for part in parts[1:]:
#                         if part.upper() == 'REFERENCES':
#                             break
#                         type_parts.append(part)
#                     column_types.append(' '.join(type_parts))
#
#                     # Extract the referenced table and column
#                     ref_idx = parts.index('REFERENCES')
#                     ref_table = parts[ref_idx + 1].split('(')[0]
#                     ref_col = parts[ref_idx + 1].split('(')[1].rstrip('),')
#                     foreign_key_refs[col_name] = (ref_table, ref_col)
#                 else:
#                     # Regular column definition
#                     parts = col_def.split()
#                     if len(parts) >= 2:
#                         col_name = parts[0]
#                         column_names.append(col_name)
#                         column_types.append(' '.join(parts[1:]))
#
#             # Create the table and add it to the schema
#             table = BaseTable(
#                 table_name=table_name,
#                 create_table_sql_statement=f"CREATE TABLE {table_name} ({table_content});",
#                 column_names=column_names,
#                 column_types=column_types,
#                 primary_key=primary_key if primary_key else 'id',
#                 foreign_key_ref=foreign_key_refs
#             )
#             self.add_table(table)
#
#     @staticmethod
#     def create_crm_schema() -> 'Schema':
#         """
#         Create the schema of our CRM database
#         """
#         schema_path = os.path.join(os.path.dirname(__file__), 'schema.sql')
#         with open(schema_path, 'r') as f:
#             schema_str = f.read()
#         return Schema(schema_str)
#
#
#
# We are transpiling the plan for this file
# ---
# We are currently trying to transpile the file database/schema.py.
# Your task: Directly transpile the file.
#
#
# # Output Format
#
# <transpilation>
# ```py
# ... Place the full transpilation here ...
# ```
# </transpilation>
#
# The `transpilation` tag should contain the full transpilation of the file.
#
#
#
#
#
# - Be careful to respect variable and function names, or the code will not compile.
# - Be sure to respect the signatures and call order.
# - Be careful to respect argument types and order, especially for object initialization.
#     - Remember that object initialization can only occur on concrete classes, not interfaces.
#     - Subsequent method calls should be on interfaces.
# - Depending on language, be sure to always unwrap/check optional types before using them.
#
#
# # Other Generic Python Guidelines
# - Assume any needed library is already installed with pip.
#     - It can just be imported like the standard libraries. For example, `import numpy as np` or `import requests`.
# - Use ''' for docstrings, instead of """.
#     - This is to help me parse and serialize the code without escaping issues.
#     - For example, `'''This is a docstring'''` instead of `"""This is a docstring"""`.
# - When generating a method in isolation, do not add the class-level indentation. I'll handle that when I put it in the class.
#
#
# # Using/Updating Python Imports
# - I have a provided a list of initial imports.
#     - In most cases, they are enough to complete the task.
# - In some cases, you may need to update the imports.
#     - Be sure the respect the paths of the code elements.
#     - If you do now know the exact, explain what you need, and I'll update them for you.
# - I will give you the option to specify new imports if needed.
#     - Leave it empty, or even absent, if no new imports are needed.
#     - Only use it if necessary.
#
#
# # Python Interface Guidelines
# Write a python interface as a regular class.
# When a method is concrete (rare), just write the method.
# When a method is abstract, raise a `NotImplementedError('Inherit me!')`.
# Unless otherwise specified, do not add fancy decorators for abstract methods or overriden methods.
#
# For example:
# ```py
# class InterfaceName:
#     '''Interface description'''
#     def abstract_method(self, arg1: int) -> str:
#         '''Abstract method description'''
#         raise NotImplementedError('Inherit me!')
#
#     def concrete_method(self, arg1: int) -> str:
#         '''Concrete method description'''
#         # Concrete method body
#         ...
#
#
# # Direct Transpilation Guidelines
# We will directly transpile the full file. You must generated complete, compilable, running code in one go.
#
# ## Re-evaluation
# In some cases, I may ask you to re-evaluate the current implementation in light of an issue/bug.
# Be sure to adjust the implementation to fix the issue/bug.
# The code should be 'stable'. Meaning that it should change only as necessary.
#
#
# # Staying Language-Agnostic
#
# Even though the specs are in Python, I am only using Python syntax for convenience.
# I want the plan to be language-agnostic and high-level, so that I may later convert it to any language.
# For example:
# - Instead of saying "Use the `request` library to make an GET request", you should say "Use an HTTP GET request to fetch the data".
# - Instead of saying "Use the `random` library to generate a random number", you should say "Generate a random number".
#
# However, you can use Python's types and standard library for variable declarations.
# - For example, you can use `t.List[int]` to denote a list of integers.
# - Or `t.IO` to denote a file object.
# - Or `t.Optional` to denote an optional value.
# - Or `t.Dict` to denote a dictionary.
# - Etc.
#
# You can also use it for fairly universal concepts such as arrays, lists, locks, classes, methods, etc which are common across languages.
# Also, arithmetic operations, control-flow operations, function calls, etc. can be in Python.
# That's because these can easily be translated to any language.
#
# Be specific about integer widths. For example, if an integer is 16-bit, 32-bit, 64-bit, etc. That's because some target languages may have different integer widths.
#
# If a class is Enum or NamedTuple, then its implementation is already complete. No need to plan it out.
#
# When something is very Python specific, you should write pseudo-code that is language-agnostic.
# Like instead of:
# x = requests.get(url)
# You should write:
# x = ... # Use an HTTP GET request to fetch the data from the URL.
#
# Instead of:
# file_handle = open("file.txt", "r")
# You should write:
# file_handle = ... # Open the file "file.txt" in read mode.
#
#
#
#
#
#
#  =============== OUTPUT: ===============
#
#
#
#
#
# I'll transpile the database/schema.py file based on the provided plan and requirements.
#
# <transpilation>
# ```py
# """
# Data models define all tables in a database.
# Use this information to write SQL statements.
# """
# import typing as t
# import re
# import os
#
#
# class BaseTable:
#     '''This is the base class for representing a table in the crm database.'''
#     def __init__(self,
#                  table_name: str,
#                  create_table_sql_statement: str,
#                  column_names: t.List[str],
#                  column_types: t.List[str],   #in postgres types (e.g., 'BIGINT', 'TEXT')
#                  primary_key: str = 'id',
#                  foreign_key_ref: t.Dict[str, t.Tuple[str]] = None,
#                  ):
#         '''Create an attribute for each of the input variables'''
#         self.table_name = table_name
#         self.create_table_sql_statement = create_table_sql_statement
#         self.column_names_list = column_names
#         self.column_types_list = column_types
#         self.primary_key = primary_key
#         self.foreign_key_ref = foreign_key_ref if foreign_key_ref else {}
#
#     def column_names(self) -> t.List[str]:
#         '''Return column names'''
#         return self.column_names_list
#
#     def column_postgres_types(self) -> t.List[str]:
#         '''Return a list of column types'''
#         return self.column_types_list
#
#     def create_table_postgres_sql(self) -> str:
#         '''Return a CREATE TABLE sql statement in Postgres syntax
#         '''
#         return self.create_table_sql_statement
#
#
# class Schema:
#     '''Holds all tables in the database schema'''
#
#     def __init__(self, schema_sql_statement: str=''):
#         '''Initialize a database schema based on the schema definition sql statement.'''
#         self.schema_sql_statement = schema_sql_statement
#         self.tables: t.List[BaseTable] = []
#         self.table_dictionary: t.Dict[str, BaseTable] = {}   # table_name: BaseTable
#         if schema_sql_statement:
#             self.get_tables_from_sql_statement()
#
#     def add_table(self, table: BaseTable):
#         """
#         Add a table to the schema, to both self.tables and self.table_dictionary
#         """
#         self.tables.append(table)
#         self.table_dictionary[table.table_name] = table
#
#     def get_tables_from_sql_statement(self):
#         """
#         Parse the self.schema_sql_statement, which contains a list of "create table" sql statements
#         Each sql statement defines table name, column names, column types, primary key and foreign key references
#         Create these tables based on the parsed results and add them.
#         Use database/schema.sql as an example.
#         """
#         # Split the SQL statement by CREATE TABLE statements
#         create_table_statements = re.findall(r'CREATE TABLE\s+(\w+)\s*\(([\s\S]*?)\);', self.schema_sql_statement, re.IGNORECASE)
#
#         for table_name, table_content in create_table_statements:
#             # Extract column definitions
#             column_defs = [col.strip() for col in table_content.split(',')]
#             column_names = []
#             column_types = []
#             primary_key = None
#             foreign_key_refs = {}
#
#             for col_def in column_defs:
#                 # Skip empty lines
#                 if not col_def:
#                     continue
#
#                 # Check if this is a primary key constraint
#                 if 'PRIMARY KEY' in col_def.upper() and not col_def.strip().startswith('('):
#                     # This is a column with PRIMARY KEY constraint
#                     parts = col_def.split()
#                     col_name = parts[0]
#                     primary_key = col_name
#                     column_names.append(col_name)
#                     column_types.append(' '.join(parts[1:-2]))  # Exclude PRIMARY KEY
#                 elif 'REFERENCES' in col_def.upper():
#                     # This is a foreign key reference
#                     parts = col_def.split()
#                     col_name = parts[0]
#                     column_names.append(col_name)
#
#                     # Extract the type (everything between column name and REFERENCES)
#                     type_parts = []
#                     for part in parts[1:]:
#                         if part.upper() == 'REFERENCES':
#                             break
#                         type_parts.append(part)
#                     column_types.append(' '.join(type_parts))
#
#                     # Extract the referenced table and column
#                     ref_idx = parts.index('REFERENCES')
#                     ref_table = parts[ref_idx + 1].split('(')[0]
#                     ref_col = parts[ref_idx + 1].split('(')[1].rstrip('),')
#                     foreign_key_refs[col_name] = (ref_table, ref_col)
#                 else:
#                     # Regular column definition
#                     parts = col_def.split()
#                     if len(parts) >= 2:
#                         col_name = parts[0]
#                         column_names.append(col_name)
#                         column_types.append(' '.join(parts[1:]))
#
#             # Create the table and add it to the schema
#             table = BaseTable(
#                 table_name=table_name,
#                 create_table_sql_statement=f"CREATE TABLE {table_name} ({table_content});",
#                 column_names=column_names,
#                 column_types=column_types,
#                 primary_key=primary_key if primary_key else 'id',
#                 foreign_key_ref=foreign_key_refs
#             )
#             self.add_table(table)
#
#     @staticmethod
#     def create_crm_schema() -> 'Schema':
#         """
#         Create the schema of our CRM database
#         """
#         schema_path = os.path.join(os.path.dirname(__file__), 'schema.sql')
#         with open(schema_path, 'r') as f:
#             schema_str = f.read()
#         return Schema(schema_str)
# ```
# </transpilation>
# /var/folders/b8/sghsj_v10yj9nmvw8ktns8100000gn/T/ipykernel_96793/2031705455.py:6: DeprecationWarning: invalid escape sequence '\s'
#   decoded = raw_string.encode().decode('unicode_escape')

# %%
for i, d in enumerate(dicts):
    if "<transpilation>" in d["output"]:
        print(d["cache_key"])
# Out:
# file_transpiler_transpilation_fundraising_crm_tree_src.database.schema_0_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.schema_2_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_0_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_2_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_4_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_6_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_7_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_9_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_11_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_13_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_14_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_16_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_18_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_20_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_21_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_23_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_25_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_27_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_28_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_30_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_32_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.database.db_operations_34_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.backend_services.data_models_0_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.backend_services.data_models_2_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.backend_services.utils_0_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.backend_services.agent_service_0_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.backend_services.agent_service_2_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.backend_services.admin_service_0_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.backend_services.admin_service_2_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_0_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_2_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_4_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_6_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_7_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_9_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_11_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_13_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_14_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_16_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_18_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_20_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_21_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_23_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_25_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_27_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_28_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_30_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_32_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.routes_34_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.app_0_sonnet3.7-nothink
# file_transpiler_transpilation_fundraising_crm_tree_src.app.app_2_sonnet3.7-nothink
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 for i, d in enumerate(dicts):
# ----> 2     if "<transpilation>" in d["output"]:
#       3         print(d["cache_key"])
#
# KeyError: 'output'

# %%
for i, d in enumerate(dicts):
    if "<analysis>" in d["output"]:
        print(d["cache_key"])

# %%
for i, d in enumerate(dicts):
    if "<transpilation>" in d["output"]:
        print(d["cache_key"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for i, d in enumerate(dicts):
#       2     if "<transpilation>" in d["output"]:
#       3         print(d["cache_key"])
#
# NameError: name 'dicts' is not defined
